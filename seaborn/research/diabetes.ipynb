# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from seaborn import objects as so

# %%
data=pd.read_csv("data/diab.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.displot(data,x="Outcome",y="Pregnancies")

# %%
sns.displot(data,x="Outcome",y="Glucose")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"Glucose")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"Pregnancies")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"BloodPressure")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"Insulin")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"BMI")

# %%
g=sns.FacetGrid(data,col="Outcome")
g.map(sns.histplot,"Age")

# %%
sns.displot(data,x="Age",y="Manipulative_Behavior",kind="kde")
