# %%
import seaborn as so
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


from seaborn import objects as so

# %%
# 3	Rape	No. of Rape cases
# 4	K&A	Kidnap And Assault
# 5	DD	Dowry Deaths
# 6	AoW	Assault against women
# 7	AoM	Assault against modesty of women
# 8	DV	Domestic violence
# 9	WT	Women Trafficking

# %%
data=pd.read_csv("data/crimes.csv")

# %%
data.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
data.describe()
# Out:
#        Unnamed: 0         Year         Rape           K&A           DD  \
# count  736.000000   736.000000   736.000000    736.000000   736.000000
# mean   367.500000  2011.149457   727.855978   1134.542120   215.692935
# std    212.609188     6.053453   977.024945   1993.536828   424.927334
# min      0.000000  2001.000000     0.000000      0.000000     0.000000
# 25%    183.750000  2006.000000    35.000000     24.750000     1.000000
# 50%    367.500000  2011.000000   348.500000    290.000000    29.000000
# 75%    551.250000  2016.000000  1069.000000   1216.000000   259.000000
# max    735.000000  2021.000000  6337.000000  15381.000000  2524.000000
#
#                 AoW          AoM            DV          WT
# count    736.000000   736.000000    736.000000  736.000000
# mean    1579.115489   332.722826   2595.078804   28.744565
# std     2463.962518   806.024551   4042.004953   79.999660
# min        0.000000     0.000000      0.000000    0.000000
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Year', 'Rape', 'K&A', 'DD', 'AoW', 'AoM', 'DV',
#        'WT'],
#       dtype='object')

# %%
state_rape=data[["State","Rape"]]

# %%
state_rape
# Out:
#                  State  Rape
# 0       ANDHRA PRADESH   871
# 1    ARUNACHAL PRADESH    33
# 2                ASSAM   817
# 3                BIHAR   888
# 4         CHHATTISGARH   959
# ..                 ...   ...
# 731         D&N Haveli  1250
# 732        Daman & Diu   315
# 733           Delhi UT     2
# 734        Lakshadweep     0
# 735         Puducherry     2
#
# [736 rows x 2 columns]

# %%
data.tail(4)
# Out:
#      Unnamed: 0        State  Year  Rape  K&A  DD   AoW  AoM   DV  WT
# 732         732  Daman & Diu  2021   315  904  16  1851   10  501   1
# 733         733     Delhi UT  2021     2    1   0     5    1    9   0
# 734         734  Lakshadweep  2021     0    0   0     1    1    3   0
# 735         735   Puducherry  2021     2    0   2    31    3   12   0

# %%
# kidnap and assault
# data is from 700 to 735
#state k& a
datatrim=data.iloc[700:735,[True,True,False,False,True,False,False,False,False,False]]

# %%
datatrim.head()
# Out:
#      Unnamed: 0              State   K&A
# 700         700     Andhra Pradesh   613
# 701         701  Arunachal Pradesh    50
# 702         702              Assam  5739
# 703         703              Bihar  8661
# 704         704       Chhattisgarh  1158

# %%
datatrim.head()
# Out:
#      Unnamed: 0              State   K&A
# 700         700     Andhra Pradesh   613
# 701         701  Arunachal Pradesh    50
# 702         702              Assam  5739
# 703         703              Bihar  8661
# 704         704       Chhattisgarh  1158

# %%
# Rape cases of year 2001
sns.barplot(datatrim, x="K&A", y="State",  legend=False)
# Out:
# <Axes: xlabel='K&A', ylabel='State'>

# %%
datatrim2=data.iloc[700:735,[True,True,False,False,False,True,False,False,False,False]]
# Rape cases of year 2001
datatrim.head()
sns.barplot(datatrim, x="DD", y="State",  legend=False)
# Out:
# <Axes: xlabel='DD', ylabel='State'>

# %%
## collect data of MH over all years:
bihar = data[(data["State"] == "Bihar") ]

# %%
bihar
# Out:
#      Unnamed: 0  State  Year  Rape   K&A    DD  AoW  AoM    DV  WT
# 343         343  Bihar  2011   934  3050  1413    0   11  2607  23
# 379         379  Bihar  2012   927  3789  1275  118   37  3686  35
# 415         415  Bihar  2013  1128  4419  1182  331   52  4533  64
# 451         451  Bihar  2014  1127  4735  2203  572  271  4672  31
# 487         487  Bihar  2015  1041  5158  1154  198   78  3792  21
# 523         523  Bihar  2016  1008  5496   987  324  124  3794  50
# 559         559  Bihar  2017   605  6182  1081  197    1  3776  24
# 595         595  Bihar  2018   651  7951  1107  262   30  2539  49
# 631         631  Bihar  2019   730  9025  1120  312   11  2397  40
# 667         667  Bihar  2020   806  6671  1046  584    6  1935  30
# 703         703  Bihar  2021   786  8661  1000  387    1  2069  32

# %%
# collect data of RJ
rajasthan=data[(data["State"]=="Rajasthan")]
rajasthan
# Out:
#      Unnamed: 0      State  Year  Rape   K&A   DD   AoW  AoM     DV  WT
# 361         361  Rajasthan  2011  1800  2713  514     0    9  12218  81
# 397         397  Rajasthan  2012  2049  2697  478  2352   18  13312  99
# 433         433  Rajasthan  2013  3285  4047  453  4829   25  15094  74
# 469         469  Rajasthan  2014  3759  4421   12  5999  727  15905  78
# 505         505  Rajasthan  2015  3644  4167  463  4813  649  14383  86
# 541         541  Rajasthan  2016  3656  4010  462  4839  483  13811  56
# 577         577  Rajasthan  2017  3305  3838  457  4883   24  11508  86
# 613         613  Rajasthan  2018  4335  4247  404  5249   34  12250  62
# 649         649  Rajasthan  2019  5997  5907  452  8802   69  18432  40
# 685         685  Rajasthan  2020    12    11    0    18    0      1   0
# 721         721  Rajasthan  2021     8     1    0    17    0      3   0

# %%
rajasthan_year_rape=rajasthan[["Year","Rape"]]
rajasthan_year_rape.head()
# Out:
#      Year  Rape
# 361  2011  1800
# 397  2012  2049
# 433  2013  3285
# 469  2014  3759
# 505  2015  3644

# %%
so.relplot(data=rajasthan_year_rape,x="Year", y="Rape")

# %%
(
    so.Plot(rajasthan_year_rape, x="Year", y="Rape")
    .add(so.Lines())
    .label(y="rape in bihar ovr years")
)

# %%
bihar_year_rape=bihar[["Year","Rape"]]
bihar_year_rape.head()
# Out:
#      Year  Rape
# 343  2011   934
# 379  2012   927
# 415  2013  1128
# 451  2014  1127
# 487  2015  1041

# %%
(
    so.Plot(bihar_year_rape, x="Year", y="Rape")
    .add(so.Lines())
    .label(y="rape in bihar ovr years")
)
