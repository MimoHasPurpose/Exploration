# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("data/antisocial.csv")
data.head()
# Out:
#    Participant_ID  Age  Gender  Apathy  Deceitfulness  Impulsivity  \
# 0               1   26    Male     4.2            3.1          4.7
# 1               2   36    Male     4.3            5.0          4.2
# 2               3   38  Female     4.3            4.8          4.2
# 3               4   28  Female     4.8            3.3          4.5
# 4               5   22  Female     3.5            4.8          4.4
#
#    Irresponsibility  Callousness  Aggressiveness  Glibness  Obtuseness  \
# 0               4.1          3.9             4.7       3.9         4.0
# 1               3.7          4.3             4.2       4.5         3.8
# 2               4.9          4.1             4.9       4.9         3.3
# 3               4.4          4.7             5.0       3.7         3.1
# 4               4.0          3.3             4.0       3.5         3.8
#
#    Lack_of_Empathy  Impulsive_Behavior  Manipulative_Behavior  \
# 0              4.3                 4.8                    3.6
# ...

# %%
temp=data[["Participant_ID","Age","Gender","Apathy"]]

# %%
sns.barplot(temp,x="Age",y="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Age'>

# %%
sns.pairplot(temp)

# %%
temp.head()
# Out:
#    Participant_ID  Age  Gender  Apathy
# 0               1   26    Male     4.2
# 1               2   36    Male     4.3
# 2               3   38  Female     4.3
# 3               4   28  Female     4.8
# 4               5   22  Female     3.5

# %%
sns.set_theme()
temp

# %%
data.head()
# Out:
#    Participant_ID  Age  Gender  Apathy  Deceitfulness  Impulsivity  \
# 0               1   26    Male     4.2            3.1          4.7
# 1               2   36    Male     4.3            5.0          4.2
# 2               3   38  Female     4.3            4.8          4.2
# 3               4   28  Female     4.8            3.3          4.5
# 4               5   22  Female     3.5            4.8          4.4
#
#    Irresponsibility  Callousness  Aggressiveness  Glibness  Obtuseness  \
# 0               4.1          3.9             4.7       3.9         4.0
# 1               3.7          4.3             4.2       4.5         3.8
# 2               4.9          4.1             4.9       4.9         3.3
# 3               4.4          4.7             5.0       3.7         3.1
# 4               4.0          3.3             4.0       3.5         3.8
#
#    Lack_of_Empathy  Impulsive_Behavior  Manipulative_Behavior  \
# 0              4.3                 4.8                    3.6
# ...

# %%
data.tail()
# Out:
#     Participant_ID  Age  Gender  Apathy  Deceitfulness  Impulsivity  \
# 27              28   38    Male     4.5            3.3          4.1
# 28              29   28    Male     3.5            3.4          4.9
# 29              30   33  Female     3.8            4.8          3.9
# 30              31   18    Male     3.3            4.9          4.8
# 31              32   23  Female     4.3            4.8          3.9
#
#     Irresponsibility  Callousness  Aggressiveness  Glibness  Obtuseness  \
# 27               3.7          4.5             4.9       3.2         3.2
# 28               4.2          4.2             4.1       3.8         3.5
# 29               4.7          4.4             3.6       4.0         3.5
# 30               4.8          3.5             4.5       4.9         3.4
# 31               3.1          3.3             4.1       4.4         4.2
#
#     Lack_of_Empathy  Impulsive_Behavior  Manipulative_Behavior  \
# ...

# %%
temp.head()
# Out:
#    Participant_ID  Age  Gender  Apathy
# 0               1   26    Male     4.2
# 1               2   36    Male     4.3
# 2               3   38  Female     4.3
# 3               4   28  Female     4.8
# 4               5   22  Female     3.5

# %%
data
# Out:
#     Participant_ID  Age  Gender  Apathy  Deceitfulness  Impulsivity  \
# 0                1   26    Male     4.2            3.1          4.7
# 1                2   36    Male     4.3            5.0          4.2
# 2                3   38  Female     4.3            4.8          4.2
# 3                4   28  Female     4.8            3.3          4.5
# 4                5   22  Female     3.5            4.8          4.4
# 5                6   31    Male     5.0            3.5          4.2
# 6                7   30  Female     4.9            3.7          4.2
# 7                8   22    Male     3.1            3.1          4.8
# 8                9   22  Female     3.3            4.8          4.2
# 9               10   18    Male     3.5            3.4          3.5
# 10              11   33  Female     4.8            4.2          3.8
# 11              12   36  Female     4.0            4.8          4.4
# 12              13   40    Male     3.2            4.6          3.6
# ...

# %%
gender_aggression=data[["Gender","Aggression"]]

# %%
gender_aggression.head()
# Out:
#    Gender  Aggression
# 0    Male         3.9
# 1    Male         4.9
# 2  Female         3.6
# 3  Female         4.2
# 4  Female         3.7

# %%
gender_aggression.sort_values(by='Gender')
# Out:
#     Gender  Aggression
# 31  Female         4.2
# 23  Female         4.5
# 17  Female         4.8
# 16  Female         4.9
# 14  Female         4.7
# 13  Female         3.7
# 25  Female         3.8
# 11  Female         3.8
# 26  Female         3.5
# 10  Female         4.1
# 6   Female         3.8
# 4   Female         3.7
# 3   Female         4.2
# 2   Female         3.6
# 29  Female         4.2
# 8   Female         5.0
# 21  Female         4.8
# 22    Male         3.8
# 27    Male         4.8
# 28    Male         3.9
# 24    Male         4.1
# 0     Male         3.9
# 19    Male         4.7
# 18    Male         4.6
# 30    Male         4.2
# 12    Male         4.5
# 9     Male         4.1
# 7     Male         3.9
# 5     Male         4.9
# 1     Male         4.9
# 20    Male         3.7
# 15    Male         3.8

# %%
gender_aggression['Gender'].value_counts()
# Out:
# Gender
# Female    17
# Male      15
# Name: count, dtype: int64

# %%
gender_aggression.describe()
# Out:
#        Aggression
# count   32.000000
# mean     4.221875
# std      0.465406
# min      3.500000
# 25%      3.800000
# 50%      4.150000
# 75%      4.700000
# max      5.000000

# %%
gendergrp=gender_aggression.groupby(['Gender'])

# %%
gendergrp.head()
# Out:
#    Gender  Aggression
# 0    Male         3.9
# 1    Male         4.9
# 2  Female         3.6
# 3  Female         4.2
# 4  Female         3.7
# 5    Male         4.9
# 6  Female         3.8
# 7    Male         3.9
# 8  Female         5.0
# 9    Male         4.1

# %%
male=gender_aggression['Gender']=='Male'

# %%
male
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25    False
# 26    False
# 27     True
# 28     True
# 29    False
# 30     True
# 31    False
# Name: Gender, dtype: bool

# %%
# Out:
# Aggression
# 3.9    3
# 4.9    2
# 4.1    2
# 3.8    2
# 4.5    1
# 4.6    1
# 4.7    1
# 3.7    1
# 4.8    1
# 4.2    1
# Name: count, dtype: int64
